# %%
from utils import *

all_triples = getAlltriples()
# Out:
# ...
# Processing Test file ../data/webnlg_dataset/raw/webnlg_release_v2.1_test.json
# 100%|██████████| 1600/1600 [00:00<00:00, 1110522.32it/s]
# 4648

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
source = [i['subject'] for i in all_triples]

target = [i['object'] for i in all_triples]

relations = [i['property'] for i in all_triples]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})
kg_df
# Out:
#                                                  source  \
# 0                              Abilene_Regional_Airport
# 1                  Adolfo_Suárez_Madrid–Barajas_Airport
# 2                  Adolfo_Suárez_Madrid–Barajas_Airport
# 3                     Afonso_Pena_International_Airport
# 4                     Afonso_Pena_International_Airport
# ...                                                 ...
# 4643  School of Business and Social Sciences at the ...
# 4644  School of Business and Social Sciences at the ...
# 4645  School of Business and Social Sciences at the ...
# 4646  School of Business and Social Sciences at the ...
# 4647  School of Business and Social Sciences at the ...
#
#                                                  target  \
# 0                                        Abilene,_Texas
# 1     "Madrid, Paracuellos de Jarama, San Sebastián ...
# 2                                             "18L/36R"
# 3                                                "SBCT"
# ...

# %%
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='red', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
with open("all_triples.json", 'w') as f:
    json.dump(all_triples, f)
    print("write into file overing...")
# Out:
# write into file overing...
